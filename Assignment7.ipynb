# %%
import pandas as pd

# %% [markdown]
# ### create series

# %%
marks = {'Rank1':95, 'Rank2':92, 'Rank3':89, 'Rank4':85, 'Rank5':80}
marks= pd.Series(marks)
print (marks)
# Out:
# Rank1    95
# Rank2    92
# Rank3    89
# Rank4    85
# Rank5    80
# dtype: int64

# %% [markdown]
# ###indexing and slicing

# %%
marks.iloc[0]
# Out:
# 95

# %%
marks.loc[['Rank1','Rank2','Rank3']]
# Out:
# Rank1    95
# Rank2    92
# Rank3    89
# dtype: int64

# %%
marks.iloc[2]
# Out:
# 89

# %%
marks[marks>90]
# Out:
# Rank1    95
# Rank2    92
# dtype: int64

# %% [markdown]
# ###manupulating series

# %%
marks["Rank1"]=100
print(marks)
# Out:
# Rank1    100
# Rank2     92
# Rank3     89
# Rank4     85
# Rank5     80
# dtype: int64

# %%
import pandas as pd

# %%
marks = pd.Series([100,92,89,85,80])
cgpa = marks / 10
print(cgpa)
# Out:
# 0    10.0
# 1     9.2
# 2     8.9
# 3     8.5
# 4     8.0
# dtype: float64

# %%
marks.drop(4,inplace = True)
print(marks)
# Out:
# 0    100
# 1     92
# 2     89
# 3     85
# dtype: int64

# %% [markdown]
# ### data frame

# %%
 transactions = {
     'TransactionID': [101, 102, 103, 104, 105, 106, 107, 108, 109, 110],
      'ProductCategory':[ 'Electronics', 'Clothing', 'Electronics', 'Furniture', 'Clothing',
                          'Electronics', 'Furniture', 'Clothing', 'Furniture', 'Electronics'],
     'Region':[ 'North', 'South', 'North', 'East', 'West', 'North', 'East', 'West', 'South', 'North'],
     'Amount':[ 200, 150, 300, 450, 200, 250, 300, 180, 350, 400]
  }

# %%
import pandas as pd

# %%
df = pd.DataFrame(transactions)

# %%
df
# Out:
#    TransactionID ProductCategory Region  Amount
# 0            101     Electronics  North     200
# 1            102        Clothing  South     150
# 2            103     Electronics  North     300
# 3            104       Furniture   East     450
# 4            105        Clothing   West     200
# 5            106     Electronics  North     250
# 6            107       Furniture   East     300
# 7            108        Clothing   West     180
# 8            109       Furniture  South     350
# 9            110     Electronics  North     400

# %% [markdown]
# ### data exploration

# %%
df.head()
# Out:
#    TransactionID ProductCategory Region  Amount
# 0            101     Electronics  North     200
# 1            102        Clothing  South     150
# 2            103     Electronics  North     300
# 3            104       Furniture   East     450
# 4            105        Clothing   West     200

# %%
df.tail()
# Out:
#    TransactionID ProductCategory Region  Amount
# 5            106     Electronics  North     250
# 6            107       Furniture   East     300
# 7            108        Clothing   West     180
# 8            109       Furniture  South     350
# 9            110     Electronics  North     400

# %%
df.shape
# Out:
# (10, 4)

# %%
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
df.dtypes
# Out:
# TransactionID       int64
# ProductCategory    object
# Region             object
# Amount              int64
# dtype: object

# %%
df[['ProductCategory','Amount']].head()
# Out:
#   ProductCategory  Amount
# 0     Electronics     200
# 1        Clothing     150
# 2     Electronics     300
# 3       Furniture     450
# 4        Clothing     200

# %%
df.loc[:,'ProductCategory':'Amount']
# Out:
#   ProductCategory Region  Amount
# 0     Electronics  North     200
# 1        Clothing  South     150
# 2     Electronics  North     300
# 3       Furniture   East     450
# 4        Clothing   West     200
# 5     Electronics  North     250
# 6       Furniture   East     300
# 7        Clothing   West     180
# 8       Furniture  South     350
# 9     Electronics  North     400

# %%
df[(df['Region']== 'North')& (df['Amount']>200)].head()
# Out:
#    TransactionID ProductCategory Region  Amount
# 2            103     Electronics  North     300
# 5            106     Electronics  North     250
# 9            110     Electronics  North     400

# %%
df.ProductCategory.value_counts()
# Out:
# ProductCategory
# Electronics    4
# Clothing       3
# Furniture      3
# Name: count, dtype: int64

# %%
df.Region.unique()
# Out:
# array(['North', 'South', 'East', 'West'], dtype=object)

# %%
mean = df.groupby('Region')['Amount'].mean()

# %%
mean
# Out:
# Region
# East     375.0
# North    287.5
# South    250.0
# West     190.0
# Name: Amount, dtype: float64

# %% [markdown]
# ### Manipulating the DataFrame

# %%
df
# Out:
#    TransactionID ProductCategory Region  Amount
# 0            101     Electronics  North     200
# 1            102        Clothing  South     150
# 2            103     Electronics  North     300
# 3            104       Furniture   East     450
# 4            105        Clothing   West     200
# 5            106     Electronics  North     250
# 6            107       Furniture   East     300
# 7            108        Clothing   West     180
# 8            109       Furniture  South     350
# 9            110     Electronics  North     400

# %%
df['Amount'] = df['Amount'].where(df['TransactionID'] != 102, 165)

# %%
df
# Out:
#    TransactionID ProductCategory Region  Amount
# 0            101     Electronics  North     200
# 1            102        Clothing  South     165
# 2            103     Electronics  North     300
# 3            104       Furniture   East     450
# 4            105        Clothing   West     200
# 5            106     Electronics  North     250
# 6            107       Furniture   East     300
# 7            108        Clothing   West     180
# 8            109       Furniture  South     350
# 9            110     Electronics  North     400

# %%
df['Discount'] = df['Amount'] * 0.10

# %%
df
# Out:
#    TransactionID ProductCategory Region  Amount  Discount
# 0            101     Electronics  North     200      20.0
# 1            102        Clothing  South     165      16.5
# 2            103     Electronics  North     300      30.0
# 3            104       Furniture   East     450      45.0
# 4            105        Clothing   West     200      20.0
# 5            106     Electronics  North     250      25.0
# 6            107       Furniture   East     300      30.0
# 7            108        Clothing   West     180      18.0
# 8            109       Furniture  South     350      35.0
# 9            110     Electronics  North     400      40.0

# %%
df = df.drop(df.index[8])

# %%
df
# Out:
#    TransactionID ProductCategory Region  Amount  Discount
# 0            101     Electronics  North     200      20.0
# 1            102        Clothing  South     165      16.5
# 2            103     Electronics  North     300      30.0
# 3            104       Furniture   East     450      45.0
# 4            105        Clothing   West     200      20.0
# 5            106     Electronics  North     250      25.0
# 6            107       Furniture   East     300      30.0
# 7            108        Clothing   West     180      18.0
# 9            110     Electronics  North     400      40.0

# %%
df = df.drop('Discount', axis=1)

# %%
df
# Out:
#    TransactionID ProductCategory Region  Amount
# 0            101     Electronics  North     200
# 1            102        Clothing  South     165
# 2            103     Electronics  North     300
# 3            104       Furniture   East     450
# 4            105        Clothing   West     200
# 5            106     Electronics  North     250
# 6            107       Furniture   East     300
# 7            108        Clothing   West     180
# 9            110     Electronics  North     400

# %% [markdown]
#  ### Data Wrangling

# %%
profitdata = {
    'TransactionID':[101, 102, 103, 105, 106, 107, 108, 109, 110],
    'Profit':[ 50, 20, 70, 40, 60, 80, 30, 90, 110]

}
df = pd.DataFrame(profitdata)

# %%
merged_df = pd.merge(df,df, on='TransactionID', how='left')

# %%
merged_df
# Out:
#    TransactionID  Profit_x  Profit_y
# 0            101        50        50
# 1            102        20        20
# 2            103        70        70
# 3            105        40        40
# 4            106        60        60
# 5            107        80        80
# 6            108        30        30
# 7            109        90        90
# 8            110       110       110

# %%
df
# Out:
#    TransactionID  Profit
# 0            101      50
# 1            102      20
# 2            103      70
# 3            105      40
# 4            106      60
# 5            107      80
# 6            108      30
# 7            109      90
# 8            110     110

# %%
additionaltransactions = {
    'TransactionID': [111, 112],
    'ProductCategory': ['Toys', 'Books'],
    'Region': ['North', 'South'],
    'Amount': [220, 170]

}

# %%
df1 = pd.DataFrame(additionaltransactions)

# %%
df1
# Out:
#    TransactionID ProductCategory Region  Amount
# 0            111            Toys  North     220
# 1            112           Books  South     170

# %%
df = pd.DataFrame(transactions)

# %%
df
# Out:
#    TransactionID ProductCategory Region  Amount
# 0            101     Electronics  North     200
# 1            102        Clothing  South     150
# 2            103     Electronics  North     300
# 3            104       Furniture   East     450
# 4            105        Clothing   West     200
# 5            106     Electronics  North     250
# 6            107       Furniture   East     300
# 7            108        Clothing   West     180
# 8            109       Furniture  South     350
# 9            110     Electronics  North     400

# %%
merged_transactions = pd.concat([df, df1], ignore_index=True)

# %%
merged_transactions
# Out:
#     TransactionID ProductCategory Region  Amount
# 0             101     Electronics  North     200
# 1             102        Clothing  South     150
# 2             103     Electronics  North     300
# 3             104       Furniture   East     450
# 4             105        Clothing   West     200
# 5             106     Electronics  North     250
# 6             107       Furniture   East     300
# 7             108        Clothing   West     180
# 8             109       Furniture  South     350
# 9             110     Electronics  North     400
# 10            111            Toys  North     220
# 11            112           Books  South     170
